# %%
import pandas as pd
from average_speed_calculator import AverageSpeedCalculator
from power_consumption_calculator import PowerConsumptionCalculator
from motor_rating_calculator import MotorRatingCalculator

class TrainSimulation:
    def __init__(self, station_chainages, mass, acceleration, max_speed, braking_deceleration, regen_efficiency, stop_duration=30):
        self.station_chainages = station_chainages
        self.mass = mass
        self.acceleration = acceleration
        self.max_speed = max_speed
        self.braking_deceleration = braking_deceleration
        self.stop_duration = stop_duration
        self.time = 0
        self.speed = 0
        self.time_log = []
        self.speed_log = []
        self.average_speed_calculator = AverageSpeedCalculator()
        self.power_calculator = PowerConsumptionCalculator(mass, regen_efficiency)
        self.motor_rating_calculator = MotorRatingCalculator(self.power_calculator, self.average_speed_calculator)

    def run_simulation(self):
        # Implement the simulation logic here using the imported classes
        # Example: acceleration, coasting, braking, etc.
        pass

# Read parameters from CSV
def load_parameters_from_csv(csv_path):
    df = pd.read_csv(csv_path)
    parameters = df.set_index('Parameter')['Value'].to_dict()
    return parameters

if __name__ == "__main__":
    csv_path = 'train_parameters.csv'  # Path to your CSV file
    params = load_parameters_from_csv(csv_path)

    # Extract station chainages (you might have a separate CSV for these)
    station_chainages = [0, 2200, 4100, 7200, 9000, 11700]  # Example data or read from CSV

    # Initialize the TrainSimulation class with parameters from the CSV
    simulation = TrainSimulation(
        station_chainages=station_chainages,
        mass=float(params['mass']),
        acceleration=float(params['acceleration']),
        max_speed=float(params['max_speed']),
        braking_deceleration=float(params['braking_deceleration']),
        regen_efficiency=float(params['regen_efficiency']),
        stop_duration=int(params['stop_duration'])
    )

    # Additional extracted values for phase calculations
    accelerating_distance = float(params['accelerating_distance'])
    switch_speed = float(params['switch_speed'])
    acceleration_switch = float(params['acceleration_switch'])
    coasting_limit = float(params['coasting_limit'])
    braking_distance = float(params['braking_distance'])

    # Run the simulation
    simulation.run_simulation()
